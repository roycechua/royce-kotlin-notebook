// %% [markdown]
// # 4 - Strings

// %%
val word = "hello "
// val words = word * 3 (doesn't exist here)
val words = word.repeat(3) // string method
println(words)
// Out:
// hello hello hello

// %%
val message1 = "hello"
val message2 = "world"
println(message1 + " " + message2)
// Out:
// hello world

// %%
val a = "hello"
val b: String? = null
println("${a + b}")
// Out:
// hellonull
